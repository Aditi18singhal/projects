# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi18singhal/projects/blob/main/Students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('student_data.csv')

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 2               2  female     group B     master's degree      standard
# 4               4    male     group C        some college      standard
# 5               5  female     group B  associate's degree      standard
# 6               6  female     group B        some college      standard
# 7               7    male     group B        some college  free/reduced
# ...           ...     ...         ...                 ...           ...
# 30635         794    male     group C        some college      standard
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19243 entries, 2 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           19243 non-null  int64
#  1   Gender               19243 non-null  object
#  2   EthnicGroup          19243 non-null  object
#  3   ParentEduc           19243 non-null  object
#  4   LunchType            19243 non-null  object
#  5   TestPrep             19243 non-null  object
#  6   ParentMaritalStatus  19243 non-null  object
#  7   PracticeSport        19243 non-null  object
#  8   IsFirstChild         19243 non-null  object
#  9   NrSiblings           19243 non-null  float64
#  10  TransportMeans       19243 non-null  object
#  11  WklyStudyHours       19243 non-null  object
#  12  MathScore            19243 non-null  int64
#  13  ReadingScore         19243 non-null  int64
#  14  WritingScore         19243 non-null  int64
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 2      female     group B     master's degree      standard       none
# 4        male     group C        some college      standard       none
# 5      female     group B  associate's degree      standard       none
# 6      female     group B        some college      standard  completed
# 7        male     group B        some college  free/reduced       none
# ...       ...         ...                 ...           ...        ...
# 30635    male     group C        some college      standard       none
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
a=df.pivot_table(index='Gender',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(a,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='Gender'>

# %%
# male are doing better in math and female are doing better in reading and writing

# %%
b=df.pivot_table(index='EthnicGroup',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(b,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='EthnicGroup'>

# %%
# students from group E and D are performing better than other groups

# %%
c=df.pivot_table(index='ParentEduc',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(c,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='ParentEduc'>

# %%
# the student's parent who has master's and bachelor's are performing better than other

# %%
d=df.pivot_table(index='LunchType',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(d,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='LunchType'>

# %%
#the students who are eating standard food are getting more score

# %%
e=df.pivot_table(index='TestPrep',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(e,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='TestPrep'>

# %%
#the student who have completed the test preparation is scoring more

# %%
f=df.pivot_table(index='ParentMaritalStatus',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(f,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='ParentMaritalStatus'>

# %%
#based on above analysis i conclude parents marital status doesn't affect students

# %%
g=df.pivot_table(index='PracticeSport',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(g,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='PracticeSport'>

# %%
#from the above analysis i conclude that the students who practice sports regularly will get better result

# %%
h=df.pivot_table(index='IsFirstChild',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(h,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='IsFirstChild'>

# %%
#from the above analysis i conclude that the result is not depending on the first child

# %%
h=df.pivot_table(index='NrSiblings',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(h,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='NrSiblings'>

# %%
#from the above analysis i conclude that the result is not depending on how many siblings

# %%
h=df.pivot_table(index='TransportMeans',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(h,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='TransportMeans'>

# %%
#from the above analysis i conclude that the score is not depending on the transportation means

# %%
h=df.pivot_table(index='WklyStudyHours',values=['MathScore','ReadingScore','WritingScore'])
sns.heatmap(h,annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='WklyStudyHours'>

# %%
#the student who study more than 10 hour score better.

# %% [markdown]
# Final conclusion: students who belong to group e and group d, has parent who has bachelor's and master's degree, who eats standard food with completion of test preparation, pratice sport regularly and has a habit studying more than 10 hour has good math,writing and reading
